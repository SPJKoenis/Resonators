# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import special 
from scipy.optimize import curve_fit
from scipy.special import erf
import math
plt.rcParams.update({'font.size': 22})

# %%
plt.figure(figsize=(15, 8))
for i in range(0,25):
    power_data = pd.read_csv (r'C:\Users\Stef\Documents\Documenten\Master\Project Russia\Resonator design\Resonator sample 1\Measurements\powerscan sample 1\fit_total %d.csv' %(i))
    plt.plot(power_data['power'], np.log10(power_data['Qi_dia_corr']))
    #plt.plot(power_data['power'], power_data['Qi_dia_corr'])

    
plt.ylim(4,6)
plt.title('Dependence of Qi on power - Experiment 1, sample 1')
plt.ylabel('Qi (log scale)')
plt.xlabel('Power (dB)')
# Out:
# C:\Users\Stef\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log10
#   after removing the cwd from sys.path.
# Text(0.5, 0, 'Power (dB)')

# %%
plt.figure(figsize=(15, 8))
for i in range(0,25):
    power_data = pd.read_csv (r'C:\Users\Stef\Documents\Documenten\Master\Project Russia\Resonator design\Resonator sample 1\Measurements\powerscan sample 2\fit_total %d.csv' %(i))
    plt.plot(power_data['power'], np.log10(power_data['Qi_dia_corr']))
    #plt.plot(power_data['power'], power_data['Qi_dia_corr'])
    
#plt.ylim(0,600000)
plt.ylim(4.5,6)
plt.title('Dependence of Qi on power - Experiment 1, sample 2')
plt.ylabel('Qi (log scale)')
plt.xlabel('Power (dB)')
# Out:
# C:\Users\Stef\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log10
#   after removing the cwd from sys.path.
# Text(0.5, 0, 'Power (dB)')
