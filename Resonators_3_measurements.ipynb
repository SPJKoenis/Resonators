# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import special

# %%
df = pd.read_excel (r'C:\Users\Stef\Documents\Documenten\Master\Project Russia\Resonator design\Resonator sample 3\Measurements\Stef_3_2_new2\Stef_3_2_new2.xlsx')
df2=df.as_matrix()
data = df2[1:61, 0:7]
freq = data[:,0]
Ql_lp = data[:,1]
Ql_hp = data[:,2]
Qe = data[:,3]
Qi_lp = data[:,4]
Qi_hp = data[:,5]

plt.plot(freq, Qi_lp)
# Out:
# C:\Users\Stef\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
